# %% [markdown]
# # 분석분야 요약서 서식(1장 이내 작성)

# %% [markdown]
# ## 활용 데이터

# %% [markdown]
# ## 분석 목적

# %% [markdown]
# ## 분석 내용

# %% [markdown]
# ## 기대 효과

# %% [markdown]
# # 분석 개요

# %% [markdown]
# ## 분석 목적

# %% [markdown]
# ## 배경 및 필요성

# %% [markdown]
# # 분석 결과 상세 내용

# %% [markdown]
# ## 분석데이터

# %% [markdown]
# ## 분석툴

# %% [markdown]
# ## 알고리즘 및 방법론

# %% [markdown]
# ## 스토리보드(선택)

# %% [markdown]
# # 결과 해석 및 시사점
# ## (결과물에 대한 해석 및 인사이트)

# %% [markdown]
# # 활용방안 및 기대효과
# ## (본 결과가 활용될 수 있는 부문 및 그 기대효과를 구체적으로 명시)

# %% [markdown]
# # 활용데이터 및 참고 문헌 출처 등
# ## (분석에 활용한 데이터 출처 명시)
# ## (참고한 관련 문헌이 있을 경우 작성)
